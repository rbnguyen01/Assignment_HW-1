# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
import cartopy.feature as feature
from cartopy.util import add_cyclic_point

# %%
pwd
# Out:
# '/home/vnguye88'

# %%
cd ..
# Out:
# /home

# %%
cd ..
# Out:
# /

# %%
cd scratch
# Out:
# /scratch

# %%
cd vnguye88
# Out:
# /scratch/vnguye88

# %%
cd dataset
# Out:
# /scratch/vnguye88/dataset

# %%
ls
# Out:
# SNDR.AIRS.AQUA.20090501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101941.nc
# SNDR.AIRS.AQUA.20100501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20110501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20120501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20130501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc
# SNDR.AIRS.AQUA.20140501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc
# SNDR.AIRS.AQUA.20150501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101948.nc
# SNDR.AIRS.AQUA.20160501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101951.nc
# SNDR.AIRS.AQUA.20170501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc
# SNDR.AIRS.AQUA.20180501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc
# SNDR.AIRS.AQUA.20190501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc
# SNDR.AIRS.AQUA.20200501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc
# data_2008_2020

# %%
ds_1 = xr.open_dataset('SNDR.AIRS.AQUA.20090501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101941.nc')
ds_2 = xr.open_dataset('SNDR.AIRS.AQUA.20100501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc')
ds_3 = xr.open_dataset('SNDR.AIRS.AQUA.20110501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc')
ds_4 = xr.open_dataset('SNDR.AIRS.AQUA.20120501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc')
ds_5 = xr.open_dataset('SNDR.AIRS.AQUA.20130501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc')
ds_6 = xr.open_dataset('SNDR.AIRS.AQUA.20140501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc')
ds_7 = xr.open_dataset('SNDR.AIRS.AQUA.20150501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101948.nc')
ds_8 = xr.open_dataset('SNDR.AIRS.AQUA.20160501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101951.nc')
ds_9 = xr.open_dataset('SNDR.AIRS.AQUA.20170501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc')
ds_10 = xr.open_dataset('SNDR.AIRS.AQUA.20180501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc')
ds_11 = xr.open_dataset('SNDR.AIRS.AQUA.20190501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc')
ds_12 = xr.open_dataset('SNDR.AIRS.AQUA.20200501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc')

# %%
print(ds_1)
# Out:
# <xarray.Dataset> Size: 398kB
# Dimensions:               (lon: 245, lat: 101, utc_tuple: 8, orbit_pass: 2)
# Coordinates:
#   * lon                   (lon) float32 980B -125.0 -124.8 ... -64.25 -64.0
#   * lat                   (lat) float32 404B 25.0 25.25 25.5 ... 49.5 49.75 50.0
#     utc_tuple_lbl         (utc_tuple) <U11 352B ...
#   * orbit_pass            (orbit_pass) timedelta64[ns] 16B 13:30:00 01:30:00
# Dimensions without coordinates: utc_tuple
# Data variables:
#     surf_air_temp         (orbit_pass, lat, lon) float32 198kB ...
#     surf_air_temp_stderr  (orbit_pass, lat, lon) float32 198kB ...
#     obs_time_utc          (orbit_pass, utc_tuple) float32 64B ...
#     obs_time_tai93        (orbit_pass) datetime64[ns] 16B ...
#     num_obs_aqua          (orbit_pass) float64 16B ...
#     num_obs_snpp          (orbit_pass) float64 16B ...
# Attributes: (12/73)
#     keywords:                          ATMOSPHERE > ATMOSPHERIC TEMPERATURE
#     Format:                            netCDF
#     Conventions:                       CF-1.6, ACDD-1.3
#     history:                           2022-05-10T19:41Z pkalmus, python fuse...
#     source:                            AIRS instrument telemetry
#     processing_level:                  3
#     ...                                ...
#     summary:                           The SSDF Level-3 AIRS-Only Near-Surfac...
#     shortname:                         SNDRAQIL3SSDFCNSAT
#     metadata_link:                     http://disc.sci.gsfc.nasa.gov/
#     references:                        Nguyen, Hai, Noel Cressie, and Amy Bra...
#     contributor_name:                  Peter Kalmus; Hai Nguyen
#     contributor_role:                  Product Developer; Algorithm Developer

# %%
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(12, 9))
lat = ds_1["lat"]
lon = ds_1["lon"]
lon2d, lat2d = np.meshgrid(lon,lat)
plt.subplot(3,4,1)
plt.contourf(lon2d, lat2d, ds_1['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2009")
plt.subplot(3,4,2)
plt.contourf(lon2d, lat2d, ds_2['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2010")
plt.subplot(3,4,3)
plt.contourf(lon2d, lat2d, ds_3['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2011")
plt.subplot(3,4,4)
plt.contourf(lon2d, lat2d, ds_4['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2012")
plt.subplot(3,4,5)
plt.contourf(lon2d, lat2d, ds_5['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2013")
plt.subplot(3,4,6)
plt.contourf(lon2d, lat2d,ds_6['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2014")
plt.subplot(3,4,7)
plt.contourf(lon2d, lat2d, ds_7['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2015")
plt.subplot(3,4,8)
plt.contourf(lon2d, lat2d, ds_8['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2016")
plt.subplot(3,4,9)
plt.contourf(lon2d, lat2d, ds_9['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2017")
plt.subplot(3,4,10)
plt.contourf(lon2d, lat2d, ds_10['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2018")
plt.subplot(3,4,11)
plt.contourf(lon2d, lat2d, ds_11['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2019")
plt.subplot(3,4,12)
plt.contourf(lon2d, lat2d, ds_12['surf_air_temp'].sel(orbit_pass="13:30:00"))
plt.title("2020")
plt.colorbar()
plt.suptitle("May Air Temperature (degKevin)")
# Out:
# Text(0.5, 0.98, 'May Air Temperature (degKevin)')

# %%
ls
# Out:
# SNDR.AIRS.AQUA.20090501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101941.nc
# SNDR.AIRS.AQUA.20100501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20110501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20120501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101943.nc
# SNDR.AIRS.AQUA.20130501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc
# SNDR.AIRS.AQUA.20140501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101947.nc
# SNDR.AIRS.AQUA.20150501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101948.nc
# SNDR.AIRS.AQUA.20160501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101951.nc
# SNDR.AIRS.AQUA.20170501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc
# SNDR.AIRS.AQUA.20180501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101952.nc
# SNDR.AIRS.AQUA.20190501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc
# SNDR.AIRS.AQUA.20200501.D01.L3_CONUS_SSDF_NSAT.std.v02_42_00.J.202205101953.nc
# data_2008_2020

# %%
cd ..
# Out:
# /scratch/vnguye88

# %%
ls
# Out:
#  Assignment_1.ipynb  'Untitled Folder 1'/
# 'Sept 18.ipynb'       Untitled.ipynb
# 'Sept 25.ipynb'       Untitled1.ipynb
# 'Sept. 30.ipynb'      Untitled2.ipynb
#  Sept11.ipynb         dataset/
#  Sept16.ipynb         subset_SNDRAQIL3SSDFCNSAT_2_20250930_015007_.txt
# 'Untitled Folder'/

# %%
rm "subset_SNDRAQIL3SSDFCNSAT_2_20250930_015007_.txt"

# %%
plt.subplot(2,2,1)
plt.contourf(ds['surf_air_temp'].sel(orbit_pass="13:30:00"))
